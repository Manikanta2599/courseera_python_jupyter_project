# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Data Science Tools and Ecosystem

# %%
## Introduction

In this notebook, Data Science Tools and Ecosystem are some of the basic skills using Markdown and python code in Jupyter Notebook as a part of my data science
# Out:
#   Cell In[2], line 3
#     In this notebook, Data Science Tools and Ecosystem are summarized.
#        ^
# SyntaxError: invalid syntax

# %%
## Data Science Languages

Some of the popular languages that Data Scientists use are:

1. Python
2. R
3. SQL
4. Java
5. Julia
6. Scala
7. JavaScript
# Out:
#   Cell In[3], line 3
#     Some of the popular languages that Data Scientists use are:
#          ^
# SyntaxError: invalid syntax

# %%
## Data Science Libraries

Some of the commonly used libraries used by Data Scientists include:

1. Pandas
2. NumPy
3. Matplotlib
4. Seaborn
5. Scikit-learn
6. Keras
7. TensorFlow
8. PyTorch
9. Apache Spark
10. ggplot2
11. PyTorch
# Out:
#   Cell In[4], line 3
#     Some of the commonly used libraries used by Data Scientists include:
#          ^
# SyntaxError: invalid syntax

# %%
## Data Science Tools

| Data Science Tools |
|--------------------|
| Jupyter Notebook |
| RStudio |
| Apache Zeppelin |
| Spyder |
| VS Code |
| Data Management | MySQL, PostgreSQL, MongoDB |
| Data Analysis | Pandas, Apache Spark |
| Machine Learning | TensorFlow, Scikit-learn, PyTorch |
| Visualization | Matplotlib, Seaborn, Tableau |
# Out:
#   Cell In[5], line 3
#     | Data Science Tools |
#     ^
# SyntaxError: invalid syntax

# %%
### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %%
**Objectives:**

- List popular languages for Data Science
- List commonly used libraries in Data Science  
- Create and format tables in markdown
- Evaluate arithmetic expressions in Python
- Perform unit conversions in Python
# Out:
#   Cell In[11], line 1
#     **Objectives:**
#     ^
# SyntaxError: invalid syntax

# %%
## Author

Manikanta Lanke
# Out:
#   Cell In[12], line 3
#     Manikanta Lanke
#               ^
# SyntaxError: invalid syntax
